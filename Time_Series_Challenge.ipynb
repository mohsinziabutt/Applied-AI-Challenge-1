# %% [markdown]
# <a href="https://colab.research.google.com/github/mohsinziabutt/Applied-AI-Challenge-1/blob/main/Time_Series_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pip install pmdarima

# %%
# To ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Packages / libraries
import os
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt

# Increases the size of sns plots
import seaborn as sns
sns.set(rc={'figure.figsize':(8,6)})

# To change scientific numbers to float
np.set_printoptions(formatter={'float_kind':'{:f}'.format})

from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn import linear_model


import itertools
import datetime
from pandas import to_datetime
from datetime import datetime
import statsmodels.api as sm

# %matplotlib inline

# %%
#################################################################################################################
########################################### Getting the CSV file     ############################################
#################################################################################################################

missing_values = ["n/a", "na", "--", "nan"]
# Loading the data
dataframe = pd.read_csv('https://raw.githubusercontent.com/mohsinziabutt/Applied-AI-Chellenge-1/main/PT_Train.csv', parse_dates=['Timestamp (GMT)'], index_col=['Timestamp (GMT)'])

# print the shape
dataframe.shape
# Out:
# (226, 4)

# %%
dataframe.isnull().sum()
# Out:
# Lifetouch Heart Rate           0
# Lifetouch Respiration Rate     0
# Oximeter SpO2                 35
# Oximeter Pulse                35
# dtype: int64

# %%
dataframe.describe()
# Out:
#        Lifetouch Heart Rate  Lifetouch Respiration Rate  Oximeter SpO2  \
# count            226.000000                  226.000000     191.000000
# mean            2315.615044                 2219.216814      83.450262
# std            11351.588825                11370.093548      29.802974
# min              106.000000                   34.000000      -1.000000
# 25%              136.000000                   38.000000      92.000000
# 50%              145.000000                   46.000000      93.000000
# 75%              156.000000                   53.000000      95.000000
# max            61442.000000                61442.000000      98.000000
#
#        Oximeter Pulse
# count      191.000000
# mean       126.335079
# std         46.348142
# min         -1.000000
# 25%        134.000000
# 50%        139.000000
# 75%        149.000000
# max        166.000000

# %%
dataframe.columns = ['LHR','LRR','OS','OP']

# %%
#xAxis = pd.to_datetime(dataframe['Time'])
#yAxis = dataframe['LHR']
plt.figure(figsize=(25,8))
plt.plot( dataframe['LHR'])
plt.title('Heart Rate vs Time')
plt.xlabel('Time(GMT)')
plt.xticks(rotation=60)
plt.ylabel('LHR')
plt.show()

# %% [markdown]
# **As we can see there are very high values in our dataset so we have to balance them first. for that we are going to take the mode of Lifetouch Heart Rate**

# %%
med = dataframe['LHR'].median()
print(med)
# Out:
# 145.0

# %% [markdown]
# **Replacing the high values with the mode**

# %%
# Limiting the columns we need
df = dataframe[['LHR']]
df.loc[(df['LHR'] >= 300),'LHR'] = int(med)

df.describe()
# Out:
#               LHR
# count  226.000000
# mean   145.831858
# std     11.130261
# min    106.000000
# 25%    136.000000
# 50%    144.500000
# 75%    155.000000
# max    172.000000

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
df.head(15)
# Out:
#                      LHR
# Timestamp (GMT)
# 2015-08-17 15:09:00  139
# 2015-08-17 15:10:00  144
# 2015-08-17 15:11:00  140
# 2015-08-17 15:12:00  138
# 2015-08-17 15:13:00  133
# 2015-08-17 15:14:00  132
# 2015-08-17 15:15:00  132
# 2015-08-17 15:16:00  133
# 2015-08-17 15:17:00  136
# 2015-08-17 15:18:00  137
# 2015-08-17 15:19:00  136
# 2015-08-17 15:20:00  137
# 2015-08-17 15:21:00  139
# 2015-08-17 15:22:00  138
# 2015-08-17 15:23:00  141

# %% [markdown]
# **Plotting the graph**

# %%
plt.figure(figsize=(25,8))
plt.plot(df)
plt.title('Heart Rate vs Time (GTM)')
plt.xlabel('Time')
plt.xticks(rotation=60)
plt.ylabel('LHR')
plt.show()

# %% [markdown]
# **Plotting the dot graph**

# %%
plt.figure(figsize=(25,8))
plt.scatter(df.index.values, df['LHR'], marker='o', s=15)
plt.title('Heart Rate vs Time (GTM)')
plt.xlabel('Time')
plt.xticks(rotation=60)
plt.ylabel('LHR')
plt.show()

# %% [markdown]
# **As we see there are three values in the graph that are below 130. Lets replace them with the average value to balance the graph**

# %%
_mean = int(df["LHR"].mean())
df.loc[(df['LHR'] < 130),'LHR'] = _mean

# %% [markdown]
# **Plotting the graph**

# %%
plt.figure(figsize=(25,8))
plt.plot(df)
plt.title('Heart Rate vs Time (GTM)')
plt.xlabel('Time')
plt.xticks(rotation=60)
plt.ylabel('LHR')
plt.show()

# %% [markdown]
# **Let's check the stationarity of the series**

# %%
from statsmodels.tsa.stattools import adfuller

def check_stationarity(series):
  # statistic, p_value, n_lags, critical_values = sm.tsa.stattools.kpss(series)
  # print(f'p value: {p_value}')
  # print(f'Result: The series is {"not " if p_value < 0.05 else ""}stationary \n')

  dfTest = adfuller(series, autolag='BIC')
  print("1. ADF : ", dfTest[0])
  print("2. P-Value : ", dfTest[1])
  print("3. Num of Lags : ", dfTest[2])
  print("4. Num of Observations : ", dfTest[3])
  print("5. Critical Values : ")

  for key, val in dfTest[4].items():
    print("\t", key, ":", val)

  print(f'Result: The series is {"not " if dfTest[1] > 0.05 else ""}stationary \n')

# %%
check_stationarity(df['LHR'])
# Out:
# 1. ADF :  -2.554293691286055
# 2. P-Value :  0.10281648942972904
# 3. Num of Lags :  0
# 4. Num of Observations :  225
# 5. Critical Values :
# 	 1% : -3.4597521044060353
# 	 5% : -2.874472927517147
# 	 10% : -2.5736628197530864
# Result: The series is not stationary

# %% [markdown]
# **As the series is not stationary so we will perfom 1st order differencing here**

# %%
df['D-LHR'] = df[['LHR']].diff(axis=0)
df = df.dropna()
df.head(15)
# Out:
#                      LHR  D-LHR
# Timestamp (GMT)
# 2015-08-17 15:10:00  144    5.0
# 2015-08-17 15:11:00  140   -4.0
# 2015-08-17 15:12:00  138   -2.0
# 2015-08-17 15:13:00  133   -5.0
# 2015-08-17 15:14:00  132   -1.0
# 2015-08-17 15:15:00  132    0.0
# 2015-08-17 15:16:00  133    1.0
# 2015-08-17 15:17:00  136    3.0
# 2015-08-17 15:18:00  137    1.0
# 2015-08-17 15:19:00  136   -1.0
# 2015-08-17 15:20:00  137    1.0
# 2015-08-17 15:21:00  139    2.0
# 2015-08-17 15:22:00  138   -1.0
# 2015-08-17 15:23:00  141    3.0
# 2015-08-17 15:24:00  139   -2.0

# %%
plt.figure(figsize=(25,8))
plt.plot(df['D-LHR'])
plt.title('Heart Rate vs Time (GTM)')
plt.xlabel('Time')
plt.xticks(rotation=60)
plt.ylabel('D-LHR')
plt.show()

# %% [markdown]
# **Now the series seems pretty much stationary but let's check it through proper method**

# %%
check_stationarity(df['D-LHR'])
# Out:
# 1. ADF :  -17.74110542887784
# 2. P-Value :  3.401867257463206e-30
# 3. Num of Lags :  0
# 4. Num of Observations :  224
# 5. Critical Values :
# 	 1% : -3.459884913337196
# 	 5% : -2.8745310704320794
# 	 10% : -2.573693840082908
# Result: The series is stationary

# %%
new_df = df['D-LHR']

split = len(new_df) - int(0.2*len(new_df))
print(f'Use {split} rows for training data')
print(f'Use {len(new_df) - split} rows for testiing data')
train = new_df[0:split]
test = new_df[split:]


print('Ttrain Data Shape', train.shape)
print('Test Data Shape', test.shape)
# Out:
# Use 180 rows for training data
# Use 45 rows for testiing data
# Ttrain Data Shape (180,)
# Test Data Shape (45,)

# %%
plt.figure(figsize=(18, 6))
plt.plot(train, color = "green")
plt.plot(test, color = "blue")
plt.ylabel('Heart Rate')
plt.xlabel('Time')
plt.title("Train / Test ")
plt.show()

# %% [markdown]
# **finding 'q' for model**

# %%
fig = plt.figure(figsize=(21,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(train, lags=80, ax=ax1)

# %% [markdown]
# **finding 'p' for model**

# %%
fig = plt.figure(figsize=(21,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_pacf(train, lags=80, ax=ax1)

# %% [markdown]
# **Finding the best value for ARIMA (19, 1, 18)**

# %% [markdown]
# **Training the model on the best values**

# %%
warnings.filterwarnings('ignore')

arima = sm.tsa.arima.ARIMA(train, order = (19,1,18))
arima_fit = arima.fit()

forecast = arima_fit.predict(start = len(train), end = test.index[-1])

# %%
print("Total Forecast Values", len(forecast), "\n")
print(forecast)
# Out:
# Total Forecast Values 45
#
# 2015-08-17 18:10:00    2.605428
# 2015-08-17 18:11:00    0.653322
# 2015-08-17 18:12:00    0.315075
# 2015-08-17 18:13:00   -0.297177
# 2015-08-17 18:14:00   -0.267891
# 2015-08-17 18:15:00    4.691541
# 2015-08-17 18:16:00   -1.731189
# 2015-08-17 18:17:00    1.811644
# 2015-08-17 18:18:00    0.133450
# 2015-08-17 18:19:00   -3.950200
# 2015-08-17 18:20:00    0.636356
# 2015-08-17 18:21:00   -3.491013
# 2015-08-17 18:22:00   -0.979674
# 2015-08-17 18:23:00   -0.778489
# 2015-08-17 18:24:00   -2.147960
# 2015-08-17 18:25:00    1.169014
# 2015-08-17 18:26:00    1.649975
# 2015-08-17 18:27:00    0.102944
# 2015-08-17 18:28:00    3.086503
# 2015-08-17 18:29:00   -0.901122
# 2015-08-17 18:30:00    1.994335
# 2015-08-17 18:31:00   -1.325308
# 2015-08-17 18:32:00    2.152614
# 2015-08-17 18:33:00    2.354219
# 2015-08-17 18:34:00   -1.228054
# 2015-08-17 18:35:00    1.349897
# 2015-08-17 18:36:00    0.431678
# 2015-08-17 18:37:00    0.267185
# 2015-08-17 18:38:00    0.958542
# 2015-08-17 18:39:00   -3.422829
# 2015-08-17 18:40:00   -1.471071
# 2015-08-17 18:41:00   -1.225023
# 2015-08-17 18:42:00   -2.862405
# 2015-08-17 18:43:00    1.628876
# 2015-08-17 18:44:00   -1.295700
# 2015-08-17 18:45:00    0.614324
# 2015-08-17 18:46:00    0.260588
# 2015-08-17 18:47:00    1.575247
# 2015-08-17 18:48:00    2.457657
# 2015-08-17 18:49:00   -0.245737
# 2015-08-17 18:50:00    0.344485
# 2015-08-17 18:51:00    1.127347
# 2015-08-17 18:52:00   -0.201905
# 2015-08-17 18:53:00    2.319564
# 2015-08-17 18:54:00   -0.051153
# Freq: T, Name: predicted_mean, dtype: float64

# %%
split = len(df) - int(0.2*len(df))
test_orignal = df[split:]

x = []
reverse_value = test + test_orignal['LHR'].shift(-1)
x.append(reverse_value)
reverted_forecast = pd.concat(x, axis=1)

reverted_forecast
# Out:
#                          0
# Timestamp (GMT)
# 2015-08-17 18:10:00  155.0
# 2015-08-17 18:11:00  153.0
# 2015-08-17 18:12:00  156.0
# 2015-08-17 18:13:00  154.0
# 2015-08-17 18:14:00  163.0
# 2015-08-17 18:15:00  144.0
# 2015-08-17 18:16:00  145.0
# 2015-08-17 18:17:00  150.0
# 2015-08-17 18:18:00  143.0
# 2015-08-17 18:19:00  152.0
# 2015-08-17 18:20:00  163.0
# 2015-08-17 18:21:00  153.0
# 2015-08-17 18:22:00  149.0
# 2015-08-17 18:23:00  156.0
# 2015-08-17 18:24:00  160.0
# 2015-08-17 18:25:00  153.0
# 2015-08-17 18:26:00  151.0
# 2015-08-17 18:27:00  159.0
# 2015-08-17 18:28:00  159.0
# 2015-08-17 18:29:00  147.0
# 2015-08-17 18:30:00  144.0
# 2015-08-17 18:31:00  147.0
# 2015-08-17 18:32:00  155.0
# 2015-08-17 18:33:00  166.0
# 2015-08-17 18:34:00  161.0
# 2015-08-17 18:35:00  161.0
# 2015-08-17 18:36:00  156.0
# 2015-08-17 18:37:00  150.0
# 2015-08-17 18:38:00  148.0
# 2015-08-17 18:39:00  141.0
# 2015-08-17 18:40:00  152.0
# 2015-08-17 18:41:00  156.0
# 2015-08-17 18:42:00  150.0
# 2015-08-17 18:43:00  151.0
# 2015-08-17 18:44:00  161.0
# 2015-08-17 18:45:00  163.0
# 2015-08-17 18:46:00  154.0
# 2015-08-17 18:47:00  151.0
# 2015-08-17 18:48:00  158.0
# 2015-08-17 18:49:00  161.0
# 2015-08-17 18:50:00  153.0
# 2015-08-17 18:51:00  132.0
# 2015-08-17 18:52:00  129.0
# 2015-08-17 18:53:00  138.0
# 2015-08-17 18:54:00    NaN

# %%
print("Total Forecast Values", len(reverted_forecast), "\n")
print(reverted_forecast)
# Out:
# Total Forecast Values 45
#
#                          0
# Timestamp (GMT)
# 2015-08-17 18:10:00  155.0
# 2015-08-17 18:11:00  153.0
# 2015-08-17 18:12:00  156.0
# 2015-08-17 18:13:00  154.0
# 2015-08-17 18:14:00  163.0
# 2015-08-17 18:15:00  144.0
# 2015-08-17 18:16:00  145.0
# 2015-08-17 18:17:00  150.0
# 2015-08-17 18:18:00  143.0
# 2015-08-17 18:19:00  152.0
# 2015-08-17 18:20:00  163.0
# 2015-08-17 18:21:00  153.0
# 2015-08-17 18:22:00  149.0
# 2015-08-17 18:23:00  156.0
# 2015-08-17 18:24:00  160.0
# 2015-08-17 18:25:00  153.0
# 2015-08-17 18:26:00  151.0
# 2015-08-17 18:27:00  159.0
# 2015-08-17 18:28:00  159.0
# 2015-08-17 18:29:00  147.0
# 2015-08-17 18:30:00  144.0
# 2015-08-17 18:31:00  147.0
# 2015-08-17 18:32:00  155.0
# 2015-08-17 18:33:00  166.0
# 2015-08-17 18:34:00  161.0
# 2015-08-17 18:35:00  161.0
# 2015-08-17 18:36:00  156.0
# 2015-08-17 18:37:00  150.0
# 2015-08-17 18:38:00  148.0
# 2015-08-17 18:39:00  141.0
# 2015-08-17 18:40:00  152.0
# 2015-08-17 18:41:00  156.0
# 2015-08-17 18:42:00  150.0
# 2015-08-17 18:43:00  151.0
# 2015-08-17 18:44:00  161.0
# 2015-08-17 18:45:00  163.0
# 2015-08-17 18:46:00  154.0
# 2015-08-17 18:47:00  151.0
# 2015-08-17 18:48:00  158.0
# 2015-08-17 18:49:00  161.0
# 2015-08-17 18:50:00  153.0
# 2015-08-17 18:51:00  132.0
# 2015-08-17 18:52:00  129.0
# 2015-08-17 18:53:00  138.0
# 2015-08-17 18:54:00    NaN

# %%
from numpy import sqrt

aic = arima_fit.aic

# 'squared=False' mean take square root using mean_squared_error method
rms_error = mean_squared_error(test.values, forecast.values, squared=False)

print("Akaike's Information Criterion (AIC): " + str(aic), "\nRoot Mean Square Error (RMSE): " + str(rms_error))
# Out:
# Akaike's Information Criterion (AIC): 961.0609256031742
# Root Mean Square Error (RMSE): 4.478436242732384

# %%
plt.figure(figsize=(18, 6))
plt.plot(train, color = "green", label="training data")
plt.plot(test, color = "blue", label="testing data")
plt.plot(forecast, color = "red", label="forecasted values")
plt.ylabel('Heart Rate')
plt.xlabel('Time')
plt.title("Time vs Heart Rate")
plt.legend()

# %% [markdown]
# **Predicting the next 20 values using the model we trained**

# %%
prediction = arima_fit.predict(start = len(df['LHR']), end = len(df['LHR']) + 19)

# %%
print("Total Predictions" ,len(prediction), "\n")
print(prediction)
# Out:
# Total Predictions 20
#
# 2015-08-17 18:55:00    1.019135
# 2015-08-17 18:56:00    0.549416
# 2015-08-17 18:57:00   -2.172490
# 2015-08-17 18:58:00    1.144659
# 2015-08-17 18:59:00   -1.417173
# 2015-08-17 19:00:00   -2.148669
# 2015-08-17 19:01:00   -1.588709
# 2015-08-17 19:02:00   -1.606464
# 2015-08-17 19:03:00    0.524708
# 2015-08-17 19:04:00    0.298129
# 2015-08-17 19:05:00    0.250371
# 2015-08-17 19:06:00    1.797922
# 2015-08-17 19:07:00   -0.439228
# 2015-08-17 19:08:00    1.716907
# 2015-08-17 19:09:00    0.981800
# 2015-08-17 19:10:00    0.896071
# 2015-08-17 19:11:00    0.745241
# 2015-08-17 19:12:00   -1.054729
# 2015-08-17 19:13:00    1.881955
# 2015-08-17 19:14:00    1.267505
# Freq: T, Name: predicted_mean, dtype: float64

# %%
plt.figure(figsize=(18, 6))
plt.plot(train, color = "green", label="training data")
plt.plot(test, color = "blue", label="testing data")
plt.plot(forecast, color = "red", label="predicted data")
plt.plot(prediction, color = "black", label="future predicted data")
plt.ylabel('Heart Rate')
plt.xlabel('Time')
plt.title("Time vs Heart Rate")
plt.legend()

# %%
x = []
reverse_value = df['LHR'] + df['D-LHR'].shift(-1)
x.append(reverse_value)
df['I-LHR'] = pd.concat(x, axis=1)

df
# Out:
#                      LHR  D-LHR  I-LHR
# Timestamp (GMT)
# 2015-08-17 15:10:00  144    5.0  140.0
# 2015-08-17 15:11:00  140   -4.0  138.0
# 2015-08-17 15:12:00  138   -2.0  133.0
# 2015-08-17 15:13:00  133   -5.0  132.0
# 2015-08-17 15:14:00  132   -1.0  132.0
# 2015-08-17 15:15:00  132    0.0  133.0
# 2015-08-17 15:16:00  133    1.0  136.0
# 2015-08-17 15:17:00  136    3.0  137.0
# 2015-08-17 15:18:00  137    1.0  136.0
# 2015-08-17 15:19:00  136   -1.0  137.0
# 2015-08-17 15:20:00  137    1.0  139.0
# 2015-08-17 15:21:00  139    2.0  138.0
# 2015-08-17 15:22:00  138   -1.0  141.0
# 2015-08-17 15:23:00  141    3.0  139.0
# 2015-08-17 15:24:00  139   -2.0  140.0
# 2015-08-17 15:25:00  140    1.0  140.0
# 2015-08-17 15:26:00  140    0.0  139.0
# 2015-08-17 15:27:00  139   -1.0  137.0
# 2015-08-17 15:28:00  137   -2.0  139.0
# 2015-08-17 15:29:00  139    2.0  139.0
# 2015-08-17 15:30:00  139    0.0  133.0
# 2015-08-17 15:31:00  133   -6.0  145.0
# 2015-08-17 15:32:00  145   12.0  139.0
# 2015-08-17 15:33:00  139   -6.0  140.0
# 2015-08-17 15:34:00  140    1.0  135.0
# 2015-08-17 15:35:00  135   -5.0  141.0
# 2015-08-17 15:36:00  141    6.0  137.0
# 2015-08-17 15:37:00  137   -4.0  145.0
# 2015-08-17 15:38:00  145    8.0  145.0
# 2015-08-17 15:39:00  145    0.0  145.0
# 2015-08-17 15:40:00  145    0.0  145.0
# 2015-08-17 15:41:00  145    0.0  145.0
# 2015-08-17 15:42:00  145    0.0  145.0
# 2015-08-17 15:43:00  145    0.0  145.0
# 2015-08-17 15:44:00  145    0.0  145.0
# 2015-08-17 15:45:00  145    0.0  136.0
# 2015-08-17 15:46:00  136   -9.0  138.0
# 2015-08-17 15:47:00  138    2.0  142.0
# 2015-08-17 15:48:00  142    4.0  145.0
# 2015-08-17 15:49:00  145    3.0  145.0
# 2015-08-17 15:50:00  145    0.0  143.0
# 2015-08-17 15:51:00  143   -2.0  139.0
# 2015-08-17 15:52:00  139   -4.0  149.0
# 2015-08-17 15:53:00  149   10.0  154.0
# 2015-08-17 15:54:00  154    5.0  152.0
# 2015-08-17 15:55:00  152   -2.0  150.0
# 2015-08-17 15:56:00  150   -2.0  144.0
# 2015-08-17 15:57:00  144   -6.0  150.0
# 2015-08-17 15:58:00  150    6.0  149.0
# 2015-08-17 15:59:00  149   -1.0  149.0
# 2015-08-17 16:00:00  149    0.0  148.0
# 2015-08-17 16:01:00  148   -1.0  144.0
# 2015-08-17 16:02:00  144   -4.0  142.0
# 2015-08-17 16:03:00  142   -2.0  142.0
# 2015-08-17 16:04:00  142    0.0  142.0
# 2015-08-17 16:05:00  142    0.0  141.0
# 2015-08-17 16:06:00  141   -1.0  140.0
# 2015-08-17 16:07:00  140   -1.0  140.0
# 2015-08-17 16:08:00  140    0.0  139.0
# 2015-08-17 16:09:00  139   -1.0  138.0
# 2015-08-17 16:10:00  138   -1.0  137.0
# 2015-08-17 16:11:00  137   -1.0  137.0
# 2015-08-17 16:12:00  137    0.0  136.0
# 2015-08-17 16:13:00  136   -1.0  137.0
# 2015-08-17 16:14:00  137    1.0  136.0
# 2015-08-17 16:15:00  136   -1.0  136.0
# 2015-08-17 16:16:00  136    0.0  136.0
# 2015-08-17 16:17:00  136    0.0  136.0
# 2015-08-17 16:18:00  136    0.0  136.0
# 2015-08-17 16:19:00  136    0.0  136.0
# 2015-08-17 16:20:00  136    0.0  137.0
# 2015-08-17 16:21:00  137    1.0  136.0
# 2015-08-17 16:22:00  136   -1.0  136.0
# 2015-08-17 16:23:00  136    0.0  136.0
# 2015-08-17 16:24:00  136    0.0  137.0
# 2015-08-17 16:25:00  137    1.0  137.0
# 2015-08-17 16:26:00  137    0.0  136.0
# 2015-08-17 16:27:00  136   -1.0  136.0
# 2015-08-17 16:28:00  136    0.0  134.0
# 2015-08-17 16:29:00  134   -2.0  134.0
# 2015-08-17 16:30:00  134    0.0  134.0
# 2015-08-17 16:31:00  134    0.0  133.0
# 2015-08-17 16:32:00  133   -1.0  132.0
# 2015-08-17 16:33:00  132   -1.0  132.0
# 2015-08-17 16:34:00  132    0.0  132.0
# 2015-08-17 16:35:00  132    0.0  132.0
# 2015-08-17 16:36:00  132    0.0  132.0
# 2015-08-17 16:37:00  132    0.0  133.0
# 2015-08-17 16:38:00  133    1.0  133.0
# 2015-08-17 16:39:00  133    0.0  133.0
# 2015-08-17 16:40:00  133    0.0  133.0
# 2015-08-17 16:41:00  133    0.0  133.0
# 2015-08-17 16:42:00  133    0.0  134.0
# 2015-08-17 16:43:00  134    1.0  134.0
# 2015-08-17 16:44:00  134    0.0  133.0
# 2015-08-17 16:45:00  133   -1.0  134.0
# 2015-08-17 16:46:00  134    1.0  134.0
# 2015-08-17 16:47:00  134    0.0  133.0
# 2015-08-17 16:48:00  133   -1.0  134.0
# 2015-08-17 16:49:00  134    1.0  134.0
# 2015-08-17 16:50:00  134    0.0  133.0
# 2015-08-17 16:51:00  133   -1.0  134.0
# 2015-08-17 16:52:00  134    1.0  134.0
# 2015-08-17 16:53:00  134    0.0  134.0
# 2015-08-17 16:54:00  134    0.0  134.0
# 2015-08-17 16:55:00  134    0.0  134.0
# 2015-08-17 16:56:00  134    0.0  138.0
# 2015-08-17 16:57:00  138    4.0  138.0
# 2015-08-17 16:58:00  138    0.0  132.0
# 2015-08-17 16:59:00  132   -6.0  133.0
# 2015-08-17 17:00:00  133    1.0  142.0
# 2015-08-17 17:01:00  142    9.0  139.0
# 2015-08-17 17:02:00  139   -3.0  146.0
# 2015-08-17 17:03:00  146    7.0  140.0
# 2015-08-17 17:04:00  140   -6.0  136.0
# 2015-08-17 17:05:00  136   -4.0  134.0
# 2015-08-17 17:06:00  134   -2.0  136.0
# 2015-08-17 17:07:00  136    2.0  131.0
# 2015-08-17 17:08:00  131   -5.0  137.0
# 2015-08-17 17:09:00  137    6.0  135.0
# 2015-08-17 17:10:00  135   -2.0  137.0
# 2015-08-17 17:11:00  137    2.0  137.0
# 2015-08-17 17:12:00  137    0.0  136.0
# 2015-08-17 17:13:00  136   -1.0  140.0
# 2015-08-17 17:14:00  140    4.0  142.0
# 2015-08-17 17:15:00  142    2.0  151.0
# 2015-08-17 17:16:00  151    9.0  146.0
# 2015-08-17 17:17:00  146   -5.0  154.0
# 2015-08-17 17:18:00  154    8.0  161.0
# 2015-08-17 17:19:00  161    7.0  158.0
# 2015-08-17 17:20:00  158   -3.0  160.0
# 2015-08-17 17:21:00  160    2.0  154.0
# 2015-08-17 17:22:00  154   -6.0  154.0
# 2015-08-17 17:23:00  154    0.0  158.0
# 2015-08-17 17:24:00  158    4.0  155.0
# 2015-08-17 17:25:00  155   -3.0  150.0
# 2015-08-17 17:26:00  150   -5.0  153.0
# 2015-08-17 17:27:00  153    3.0  155.0
# 2015-08-17 17:28:00  155    2.0  158.0
# 2015-08-17 17:29:00  158    3.0  163.0
# 2015-08-17 17:30:00  163    5.0  162.0
# 2015-08-17 17:31:00  162   -1.0  162.0
# 2015-08-17 17:32:00  162    0.0  163.0
# 2015-08-17 17:33:00  163    1.0  163.0
# 2015-08-17 17:34:00  163    0.0  160.0
# 2015-08-17 17:35:00  160   -3.0  159.0
# 2015-08-17 17:36:00  159   -1.0  160.0
# 2015-08-17 17:37:00  160    1.0  159.0
# 2015-08-17 17:38:00  159   -1.0  166.0
# 2015-08-17 17:39:00  166    7.0  164.0
# 2015-08-17 17:40:00  164   -2.0  161.0
# 2015-08-17 17:41:00  161   -3.0  167.0
# 2015-08-17 17:42:00  167    6.0  159.0
# 2015-08-17 17:43:00  159   -8.0  152.0
# 2015-08-17 17:44:00  152   -7.0  152.0
# 2015-08-17 17:45:00  152    0.0  150.0
# 2015-08-17 17:46:00  150   -2.0  151.0
# 2015-08-17 17:47:00  151    1.0  155.0
# 2015-08-17 17:48:00  155    4.0  159.0
# 2015-08-17 17:49:00  159    4.0  154.0
# 2015-08-17 17:50:00  154   -5.0  157.0
# 2015-08-17 17:51:00  157    3.0  163.0
# 2015-08-17 17:52:00  163    6.0  158.0
# 2015-08-17 17:53:00  158   -5.0  163.0
# 2015-08-17 17:54:00  163    5.0  164.0
# 2015-08-17 17:55:00  164    1.0  166.0
# 2015-08-17 17:56:00  166    2.0  169.0
# 2015-08-17 17:57:00  169    3.0  169.0
# 2015-08-17 17:58:00  169    0.0  170.0
# 2015-08-17 17:59:00  170    1.0  172.0
# 2015-08-17 18:00:00  172    2.0  165.0
# 2015-08-17 18:01:00  165   -7.0  163.0
# 2015-08-17 18:02:00  163   -2.0  156.0
# 2015-08-17 18:03:00  156   -7.0  156.0
# 2015-08-17 18:04:00  156    0.0  161.0
# 2015-08-17 18:05:00  161    5.0  161.0
# 2015-08-17 18:06:00  161    0.0  164.0
# 2015-08-17 18:07:00  164    3.0  160.0
# 2015-08-17 18:08:00  160   -4.0  158.0
# 2015-08-17 18:09:00  158   -2.0  159.0
# 2015-08-17 18:10:00  159    1.0  154.0
# 2015-08-17 18:11:00  154   -5.0  158.0
# 2015-08-17 18:12:00  158    4.0  152.0
# 2015-08-17 18:13:00  152   -6.0  160.0
# 2015-08-17 18:14:00  160    8.0  155.0
# 2015-08-17 18:15:00  155   -5.0  149.0
# 2015-08-17 18:16:00  149   -6.0  151.0
# 2015-08-17 18:17:00  151    2.0  148.0
# 2015-08-17 18:18:00  148   -3.0  146.0
# 2015-08-17 18:19:00  146   -2.0  154.0
# 2015-08-17 18:20:00  154    8.0  155.0
# 2015-08-17 18:21:00  155    1.0  152.0
# 2015-08-17 18:22:00  152   -3.0  152.0
# 2015-08-17 18:23:00  152    0.0  156.0
# 2015-08-17 18:24:00  156    4.0  156.0
# 2015-08-17 18:25:00  156    0.0  153.0
# 2015-08-17 18:26:00  153   -3.0  154.0
# 2015-08-17 18:27:00  154    1.0  158.0
# 2015-08-17 18:28:00  158    4.0  155.0
# 2015-08-17 18:29:00  155   -3.0  150.0
# 2015-08-17 18:30:00  150   -5.0  149.0
# 2015-08-17 18:31:00  149   -1.0  148.0
# 2015-08-17 18:32:00  148   -1.0  156.0
# 2015-08-17 18:33:00  156    8.0  158.0
# 2015-08-17 18:34:00  158    2.0  159.0
# 2015-08-17 18:35:00  159    1.0  160.0
# 2015-08-17 18:36:00  160    1.0  155.0
# 2015-08-17 18:37:00  155   -5.0  155.0
# 2015-08-17 18:38:00  155    0.0  148.0
# 2015-08-17 18:39:00  148   -7.0  148.0
# 2015-08-17 18:40:00  148    0.0  152.0
# 2015-08-17 18:41:00  152    4.0  152.0
# 2015-08-17 18:42:00  152    0.0  150.0
# 2015-08-17 18:43:00  150   -2.0  153.0
# 2015-08-17 18:44:00  153    3.0  158.0
# 2015-08-17 18:45:00  158    5.0  158.0
# 2015-08-17 18:46:00  158    0.0  154.0
# 2015-08-17 18:47:00  154   -4.0  155.0
# 2015-08-17 18:48:00  155    1.0  157.0
# 2015-08-17 18:49:00  157    2.0  159.0
# 2015-08-17 18:50:00  159    2.0  151.0
# 2015-08-17 18:51:00  151   -8.0  140.0
# 2015-08-17 18:52:00  140  -11.0  140.0
# 2015-08-17 18:53:00  140    0.0  138.0
# 2015-08-17 18:54:00  138   -2.0    NaN

# %%
reverted_pred = np.hstack((df['LHR'][0], prediction)).cumsum()
reverted_pred = reverted_pred.round(0).astype(int)

print("Total Conversions", len(reverted_pred), "\n")
print(reverted_pred)
# Out:
# Total Conversions 21
#
# [144 145 146 143 145 143 141 139 138 138 139 139 141 140 142 143 144 145
#  143 145 147]

# %%
reverted_pred = np.delete(reverted_pred, 0)
print("Total Conversions", len(reverted_pred), "\n")
print(reverted_pred)
# Out:
# Total Conversions 20
#
# [145 146 143 145 143 141 139 138 138 139 139 141 140 142 143 144 145 143
#  145 147]

# %%
plt.figure(figsize=(18, 6))
plt.plot(df['LHR'], color = "blue", label="Orignal Data")
plt.plot(df['I-LHR'], color = "red", label="Inverted-Diff Data")
plt.ylabel('Heart Rate')
plt.xlabel('Time')
plt.title("Time vs Heart Rate")
plt.legend()

# %%
plt.figure(figsize=(18, 4))
plt.plot(reverted_forecast, color = "green", label="Inverted-Frcst data")
plt.ylabel('Heart Rate')
plt.xlabel('Time')
plt.title("Time vs Heart Rate")
plt.legend()

# %%
new_df = pd.DataFrame([], columns=['Timestamp (GMT)', 'Pred-LHR'])

new_df['Pred-LHR'] = reverted_pred
new_df['Timestamp (GMT)'] = prediction.index
# new_df.reset_index(drop=True, inplace=True)
new_df.set_index('Timestamp (GMT)', inplace=True)

# %%
plt.figure(figsize=(18, 4))
plt.plot(new_df, color = "black", label="Predicted Data")
plt.ylabel('Heart Rate')
plt.xlabel('Time')
plt.title("Time vs Heart Rate")
plt.legend()

# %%
plt.figure(figsize=(18, 6))
plt.plot(df['LHR'], color = "blue", label="Orignal Data")
plt.plot(df['I-LHR'], color = "red", label="Inverted-Diff Data")
plt.plot(reverted_forecast, color = "green", label="Inverted-Frcst data")
plt.plot(new_df, color = "black", label="Predicted Data")
plt.ylabel('Heart Rate')
plt.xlabel('Time')
plt.title("Time vs Heart Rate")
plt.legend()

# %%
new_df.to_csv('New_LHR_Predictions.csv', header=True)
